# %% [markdown]
# <img src="../images/QISKit-c.gif" alt="Note: In order for images to show up in this jupyter notebook you need to select File => Trusted Notebook" width="250 px" align="left">

# %% [markdown]
# ## _*VQE algorithm: Application to quantum chemistry*_
#
# The latest version of this notebook is available on https://github.com/QISKit/qiskit-tutorial.
#
# For more information about how to use the IBM Q experience (QX), consult the [tutorials](https://quantumexperience.ng.bluemix.net/qstage/#/tutorial?sectionId=c59b3710b928891a1420190148a72cce&pageIndex=0), or check out the [community](https://quantumexperience.ng.bluemix.net/qstage/#/community).
#
# ***
# ### Contributors
# Antonio Mezzacapo, Jay Gambetta

# %% [markdown]
# ### Introduction
#
# One of the most compelling possibilities of quantum computation is the the simulation of other quantum systems. Quantum simulation of quantum systems encompasses a wide range of tasks, including most significantly:
#
# 1. Simulation of the time evolution of quantum systems.
#
# 2. Computation of ground state properties.
#
# These applications are especially useful when considering systems of interacting fermions, such as molecules and strongly correlated materials. The computation of ground state properties of fermionic systems is the starting point for mapping out the phase diagram of condensed matter Hamiltonians. It also gives access to the key question of electronic structure problems in quantum chemistry, namely reaction rates. The focus of this notebook is on molecular systems, which are considered to be the ideal bench test for early-stage quantum computers, due to their relevance in chemical applications despite relatively modest sizes. Formally, the ground state problem asks the following:
#
# For some physical Hamiltonian *H*, find the smallest eigenvalue $E_G$, such that $H|\psi_G\rangle=E_G|\psi_G\rangle$, where $|\Psi_G\rangle$ is the eigenvector corresponding to $E_G$.
#
# It is known that in general this problem is intractable, even on a quantum computer. This means that we cannot expect an efficient quantum algorithm that prepares the ground state of general local Hamiltonians. Despite this limitation, for specific Hamiltonians of interest it might be possible, given physical constraints on the interactions, to solve the above problem efficiently. Currently, at least four different methods exist to approach this problem:
#
# 1. Quantum phase estimation: Assuming that we can approximately prepare the state $|\psi_G\rangle$, this routine uses controlled implementations of the Hamiltonian to find its smallest eigenvalue.
# 2. Adiabatic theorem of quantum mechanics: The quantum system is adiabatically dragged from being the ground state of a trivial Hamiltonian to the one of the target problem, via slow modulation of the Hamiltonian terms.
# 3. Dissipative (non-unitary) quantum operation: The ground state of the target system is a fixed point. The non-trivial assumption here is the implementation of the dissipation map on quantum hardware.
# 4. Variational quantum eigensolvers: Here we assume that the ground state can be represented by a parameterization containing a relatively small number of parameters.
#
# In this notebook we focus on the last method, as this is most likely the simplest to be realized on near-term devices.
#
# The general idea is to define a parameterization $|\psi(\boldsymbol\theta)\rangle$ of quantum states, and minimize the energy
#
# $$E(\boldsymbol\theta) = \langle \psi(\boldsymbol\theta)| H |\psi(\boldsymbol\theta)\rangle,$$
#
# The key ansatz is that the number of parameters $|\boldsymbol\theta^*|$ that minimizes the energy function scales polynomially with the size (e.g., number of qubits) of the target problem.
#
# Then, any local fermionic Hamiltonian can be mapped into a sum over Pauli operators $P_i$,
#
# $$H\rightarrow H_P = \sum_i^M w_i P_i,$$
#
# and the energy corresponding to the state $|\psi(\boldsymbol\theta\rangle$, $E(\boldsymbol\theta)$, can be estimated by sampling the individual Pauli terms $P_i$ (or sets of them that can be measured at the same time) on a quantum computer
#
# $$E(\boldsymbol\theta) = \sum_i^M w_i \langle \psi(\boldsymbol\theta)| P_i |\psi(\boldsymbol\theta)\rangle.$$
#
# Last, some optimization technique has to be devised in order to find the optimal value of parameters $\boldsymbol\theta^*$, such that $|\psi(\boldsymbol\theta^*)\rangle\equiv|\psi_G\rangle$.
#
#
#
# ### Fermionic Hamiltonians
#
# The Hamiltonians describing systems of interacting fermions can be expressed in second quantization language, considering fermionic creation (annihilation) operators $a^\dagger_\alpha(a_\alpha)$, relative to the $\alpha$-th fermionic mode. In the case of molecules, the $\alpha$ labels stand for the different atomic or molecular orbitals. Within the second-quantization framework, a generic molecular Hamiltonian with $M$ orbitals can be written as
# $$H =H_1+H_2=\sum_{\alpha, \beta=0}^{M-1} t_{\alpha \beta} \, a^\dagger_{\alpha} a_{\beta} +\frac{1}{2}  \sum_{\alpha, \beta, \gamma, \delta = 0}^{M-1} u_{\alpha \beta \gamma \delta}\, a^\dagger_{\alpha} a^\dagger_{\gamma} a_{\delta} a_{\beta},$$
# with the one-body terms representing the kinetic energy of the electrons and the potential energy that they experience in the presence of the nuclei,
# $$ t_{\alpha\beta}=\int d\boldsymbol x_1\Psi_\alpha(\boldsymbol{x}_1) \left(-\frac{\boldsymbol\nabla_1^2}{2}+\sum_{i} \frac{Z_i}{|\boldsymbol{r}_{1i}|}\right)\Psi_\beta (\boldsymbol{x}_1),$$
# and their interactions via Coulomb forces
# $$ u_{\alpha\beta\gamma\delta}=\int\int d \boldsymbol{x}_1 d \boldsymbol{x}_2 \Psi_\alpha^*(\boldsymbol{x}_1)\Psi_\beta(\boldsymbol{x}_1)\frac{1}{|\boldsymbol{r}_{12}|}\Psi_\gamma^*(\boldsymbol{x}_2)\Psi_\delta(\boldsymbol{x}_2),$$
# where we have defined the nuclei charges $Z_i$, the nuclei-electron and electron-electron separations $\boldsymbol{r}_{1i}$ and $\boldsymbol{r}_{12}$, the $\alpha$-th orbital wavefunction $\Psi_\alpha(\boldsymbol{x}_1)$, and we have assumed that the spin is conserved in the spin-orbital indices $\alpha,\beta$ and $\alpha,\beta,\gamma,\delta$.
#
# ### Molecules considered in this notebook and mapping to qubits
#
# We consider in this notebook the optimization of two potential energy surfaces, for the hydrogen and lithium hydride molecules, obtained using the STO-3G basis. The molecular Hamiltonians are computed as a function of their interatomic distance, then mapped to two- (H$_2$) and four- (LiH$_2$) qubit problems, via elimination of core and high-energy orbitals and removal of $Z_2$ symmetries.
#
# ### Approximate universal quantum computing for quantum chemisty problems
#
# In order to find the optimal parameters $\boldsymbol\theta^*$, we set up a closed optimization loop with a quantum computer, based on some stochastic optimization routine. Our choice for the variational ansatz is a deformation of the one used for the optimization of classical combinatorial problems, with the inclusion of $Z$ rotation together with the $Y$ ones. The optimization algorithm for fermionic Hamiltonians is similar to the one for combinatorial problems, and can be summarized as follows:
#
#
# 1. Map the fermionic Hamiltonian $H$ to a qubit Hamiltonian $H_P$.
# 2. Choose the maximum depth of the quantum circuit (this could be done adaptively).
# 3. Choose a set of controls $\boldsymbol\theta$ and make a trial function $|\psi(\boldsymbol\theta)\rangle$. The difference with the combinatorial problems is the insertion of additional parametrized $Z$ single-qubit rotations.
# 4. Evaluate the energy $E(\boldsymbol\theta) = \langle\psi(\boldsymbol\theta)~|H_P|~\psi(\boldsymbol\theta)\rangle$ by sampling each Pauli term individually, or sets of Pauli terms that can be measured in the same tensor product basis.
# 5. Use a classical optimizer to choose a new set of controls.
# 6. Continue until the energy has converged, hopefully close to the real solution $\boldsymbol\theta^*$ and return the last value of $E(\boldsymbol\theta)$.
#
#
# Note that, as opposed to the classical case, in the case of a quantum chemistry Hamiltonian one has to sample over non-computational states that are superpositions, and therefore take advantage of using a quantum computer in the sampling part of the algorithm. Motivated by the quantum nature of the answer, we also define a variational trial ansatz in this way:
#
# $$|\psi(\boldsymbol\theta)\rangle  = [U_\mathrm{single}(\boldsymbol\theta) U_\mathrm{entangler}]^m |+\rangle$$
#
# where $U_\mathrm{entangler}$ is a collection of cPhase gates (fully entangling gates), $U_\mathrm{single}(\boldsymbol\theta) = \prod_{i=1}^n Y(\theta_{i})Z(\theta_{n+i})$ are single-qubit $Y$ and $Z$ rotation, $n$ is the number of qubits and $m$ is the depth of the quantum circuit.
#
#
#
# References and additional details:
#
# [1] A. Kandala, A. Mezzacapo, K. Temme, M. Takita, J. M. Chow, and J. M. Gambetta, *Hardware-efficient Quantum Optimizer for Small Molecules and Quantum Magnets*, e-print arXiv 1704.0501, and references therein.

# %%
# Checking the version of PYTHON; we only support 3 at the moment
import sys
if sys.version_info < (3,0):
    raise Exception('Please use Python version 3 or greater.')
    
# useful additional packages 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from scipy import linalg as la
from functools import partial

import sys
sys.path.append('../../qiskit-sdk-py-dev/')
# importing the QISKit

from qiskit import QuantumCircuit, QuantumProgram
import Qconfig
import math

# import basic plot tools
from tools.visualization import plot_histogram

# import optimization tools
from tools.apps.optimization import trial_circuit_ryrz,trial_circuit_ry, SPSA_optimization, SPSA_calibration
from tools.apps.optimization import Energy_Estimate, Measure_pauli_z, Hamiltonian_from_file, make_Hamiltonian
from tools.qi.pauli import Pauli, label_to_pauli
from tools.apps.fermion import fermionic_maps, two_qubit_reduction

def eval_hamiltonian(Q_program,n,m,file_name,device,shots,H,theta):
    avg_energy=0
    var_energy=0
    std_energy=0

    # STACK QUANTUM CIRCUITS ASSOCIATED TO EACH PAULI TERM AND EXECUTE THEM 
    if shots!=1: 
        circuits=[]
        trial_circuit=[]
        
        file = open(file_name, 'r+')
        ham_array = file.readlines()
        ham_array = [x.strip() for x in ham_array]
        
        for i in range(len(ham_array)//2):     

            trial_circuit.append(trial_circuit_ryrz(n,m,theta,entangler_map,ham_array[i*2],True))
            circuits.append('trial_circuit_label'+str(i))
            Q_program.add_circuit(circuits[i],trial_circuit[i])
   
        file.close()

        # EXECUTE THE CIRCUITS STACKED 

        result = Q_program.execute(circuits,device,shots=shots,silent=True)
    
        pauli_list=Hamiltonian_from_file(file_name)

        for i in range(len(ham_array)//2):#loop over Pauli terms

            pauli_avg=Energy_Estimate(result.get_counts('trial_circuit_label'+str(i)),pauli_list[i])
            avg_energy+=pauli_avg
    
    else:
    
        circuit=['circuit']
        Q_program.add_circuit(circuit[0],trial_circuit_ryrz(n,m,theta,entangler_map,None,False))
        result = Q_program.execute(circuit,device,shots=shots,silent=True)
        avg_energy=(np.inner(np.conjugate(result.get_data(circuit[0])['quantum_state']),np.dot(H,result.get_data(circuit[0])['quantum_state']))).real
        
    
    return avg_energy, std_energy

# %% [markdown]
# ## Optimization of H2 at bond length
#
# In this first part of the notebook we show the optimization of the H$_2$ Hamiltonian in the STO-3G basis at the bond length of 0.735 Angstrom. After mapping it to a four-qubit system with a binary-tree transformation, two spin-parity symmetries are modded out, leading to a two-qubit Hamiltonian. The energy of the mapped Hamiltonian obtained is then minimized using the variational ansatz described in the introduction, and a stochastic perturbation simultaneous approximation (SPSA) gradient descent method.

# %%
n=2
m=2
device='local_qasm_simulator'

initial_theta=np.zeros(2*n*m)
entangler_map={0: [1]} # the map of two-qubit gates with control at key and target at values
shots=1
max_trials=100
ham_name='H2/H2Equilibrium.txt'

# Exact Energy
pauli_list=Hamiltonian_from_file(ham_name)
H=make_Hamiltonian(pauli_list)
exact=np.amin(la.eig(H)[0]).real
         
# Optimization
Q_program = QuantumProgram()
Q_program.set_api(Qconfig.APItoken,Qconfig.config["url"])

eval_hamiltonian_partial=partial(eval_hamiltonian,Q_program,n,m,ham_name,device,shots,H)
eval_hamiltonian_partial(initial_theta)

initial_c=0.1
target_update=2*np.pi*0.1
SPSA_params=SPSA_calibration(eval_hamiltonian_partial,initial_theta,initial_c,target_update,25)
save_step=20

output=SPSA_optimization(eval_hamiltonian_partial,initial_theta,SPSA_params,max_trials,save_step,1);
# Out:
# calibration step # 0 of 25
# calibration step # 5 of 25
# calibration step # 10 of 25
# calibration step # 15 of 25
# calibration step # 20 of 25
# calibrated SPSA_parameters[0] is 1.33102197054
# objective function at theta+ for step # 0
# -0.87717157231
# objective function at theta- for step # 0
# -0.883722388395
# objective function at theta+ for step # 20
# -1.78397753562
# objective function at theta- for step # 20
# -1.7612460132
# objective function at theta+ for step # 40
# -1.82964534205
# objective function at theta- for step # 40
# -1.82077490054
# objective function at theta+ for step # 60
# -1.8263067666
# objective function at theta- for step # 60
# -1.83913082669
# objective function at theta+ for step # 80
# -1.83362261833
# objective function at theta- for step # 80
# -1.83597333269
# Final objective function is: -1.84897964138

# %%
plt.plot(np.arange(0, max_trials,save_step),output[2],label='E(theta_plus)')
plt.plot(np.arange(0, max_trials,save_step),output[3],label='E(theta_minus)')
plt.plot(np.arange(0, max_trials,save_step),np.ones(max_trials//save_step)*output[0],label='Final Energy')
plt.plot(np.arange(0, max_trials,save_step),np.ones(max_trials//save_step)*exact,label='Exact Energy')
plt.legend()
plt.xlabel('Trial state')
plt.ylabel('Energy')

# %% [markdown]
# ## Optimizing the potential energy surface
#
# The optimization considered previously is now performed for two molecules, H$_2$ and LiH, for different interatomic distances, and the correspoding nuclei Coulomb repulsion is added in order to obtain a potential energy surface.

# %%
# MOLECULE PARAMETERS

molecule='H2' # name of the molecule: options are H2 or LiH

if molecule=='H2':
    n=2 # qubits
    Z1=1
    Z2=1
    min_distance=.2
    max_distance=4
    number_of_points=39
elif molecule=='LiH':
    n=4 # qubits
    Z1=1
    Z2=3
    min_distance=.5
    max_distance=5
    number_of_points=46
    
# OPTIMIZATION PARAMETERS 

run_optimization=True # Choose True or False. False just plots the exact potential energy surface

m=2 # depth (number of layers of sq gates - # entanglers is this number -1)
device='local_qasm_simulator'
initial_theta=np.random.randn(2*n*m)  # initial angles 
entangler_map={0: [1]} # the map of two-qubit gates with control at key and target at values
shots=1
max_trials=800

initial_c=0.01
target_update=2*np.pi*0.1

####################     COMPUTING THE POTENTIAL ENERGY SURFACE      ###################

mol_distance=np.zeros(number_of_points)
coulomb_repulsion=np.zeros(number_of_points)
electr_energy=np.zeros(number_of_points)
electr_energy_optimized=np.zeros(number_of_points)

Q_program = QuantumProgram()
Q_program.set_api(Qconfig.APItoken,Qconfig.config["url"])

for i in range(number_of_points):

    # %%%%%%%%%%%%% Coulomb Repulsion For Diatomic Molecules %%%%%%%%%%%%%%%%%%%%%%
        mol_distance[i]=np.around((min_distance+(max_distance-min_distance)*i/(number_of_points-1)),2)
        
        distance=mol_distance[i]/0.529177
        coulomb_repulsion[i]=Z1*Z2/distance
        
    # exact diagonalization
        ham_text=molecule+'/PESMap'+str(i)+'atdistance'+str(mol_distance[i])+'.txt'
        pauli_list=Hamiltonian_from_file(ham_text)
        H=make_Hamiltonian(pauli_list)
        eigen=la.eig(H)
        electr_energy[i]=np.amin(eigen[0])
           
    # optimization
    
        if run_optimization:
            print('\nOPTIMIZING HAMILTONIAN # '+str(i)+' AT INTERATOMIC DISTANCE '+str(mol_distance[i])+' ANGSTROM\n')
            eval_hamiltonian_partial=partial(eval_hamiltonian,Q_program,n,m,ham_name,device,shots,H)
            SPSA_params=SPSA_calibration(eval_hamiltonian_partial,initial_theta,initial_c,target_update,5)
            electr_energy_optimized[i]=SPSA_optimization(eval_hamiltonian_partial,initial_theta,SPSA_params,max_trials,100)[0]
# Out:
# /Users/jmgambet/anaconda/envs/QISKitenv/lib/python3.6/site-packages/ipykernel_launcher.py:57: ComplexWarning: Casting complex values to real discards the imaginary part
# OPTIMIZING HAMILTONIAN # 0 AT INTERATOMIC DISTANCE 0.2 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 0.571252089477
# objective function at theta+ for step # 0
# -0.189740436491
# objective function at theta- for step # 0
# -0.183764791186
# objective function at theta+ for step # 100
# -2.48049259697
# objective function at theta- for step # 100
# -2.48069449149
# objective function at theta+ for step # 200
# -2.48401676011
# objective function at theta- for step # 200
# -2.48393449858
# objective function at theta+ for step # 300
# -2.48407795004
# objective function at theta- for step # 300
# -2.48408197736
# objective function at theta+ for step # 400
# -2.48430098201
# objective function at theta- for step # 400
# -2.48414802266
# objective function at theta+ for step # 500
# -2.48426171558
# objective function at theta- for step # 500
# -2.4844199974
# objective function at theta+ for step # 600
# -2.4844624001
# objective function at theta- for step # 600
# -2.48445813326
# objective function at theta+ for step # 700
# -2.48461429409
# objective function at theta- for step # 700
# -2.48472685388
# Final objective function is: -2.48482089484
#
# OPTIMIZING HAMILTONIAN # 1 AT INTERATOMIC DISTANCE 0.3 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 0.783076341411
# objective function at theta+ for step # 0
# -0.357006257847
# objective function at theta- for step # 0
# -0.370869659843
# objective function at theta+ for step # 100
# -2.36006103702
# objective function at theta- for step # 100
# -2.35981897653
# objective function at theta+ for step # 200
# -2.36050134868
# objective function at theta- for step # 200
# -2.36040301586
# objective function at theta+ for step # 300
# -2.36093896943
# objective function at theta- for step # 300
# -2.36076105218
# objective function at theta+ for step # 400
# -2.36118648485
# objective function at theta- for step # 400
# -2.36117414513
# objective function at theta+ for step # 500
# -2.36140673254
# objective function at theta- for step # 500
# -2.36133732308
# objective function at theta+ for step # 600
# -2.36182371776
# objective function at theta- for step # 600
# -2.36166354527
# objective function at theta+ for step # 700
# -2.36198538575
# objective function at theta- for step # 700
# -2.36180778099
# Final objective function is: -2.36219405927
#
# OPTIMIZING HAMILTONIAN # 2 AT INTERATOMIC DISTANCE 0.4 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 1.43703584354
# objective function at theta+ for step # 0
# -0.533422059131
# objective function at theta- for step # 0
# -0.527277237367
# objective function at theta+ for step # 100
# -2.2352720371
# objective function at theta- for step # 100
# -2.23517237322
# objective function at theta+ for step # 200
# -2.23591355484
# objective function at theta- for step # 200
# -2.23594812987
# objective function at theta+ for step # 300
# -2.23617588582
# objective function at theta- for step # 300
# -2.23632416661
# objective function at theta+ for step # 400
# -2.23642025376
# objective function at theta- for step # 400
# -2.23653137067
# objective function at theta+ for step # 500
# -2.2366326475
# objective function at theta- for step # 500
# -2.23661914944
# objective function at theta+ for step # 600
# -2.23663644564
# objective function at theta- for step # 600
# -2.23663406362
# objective function at theta+ for step # 700
# -2.23669123283
# objective function at theta- for step # 700
# -2.23672100242
# Final objective function is: -2.23687428632
#
# OPTIMIZING HAMILTONIAN # 3 AT INTERATOMIC DISTANCE 0.5 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 0.650712629642
# objective function at theta+ for step # 0
# -0.658287942052
# objective function at theta- for step # 0
# -0.672932863714
# objective function at theta+ for step # 100
# -2.10989968742
# objective function at theta- for step # 100
# -2.10996229483
# objective function at theta+ for step # 200
# -2.111052385
# objective function at theta- for step # 200
# -2.11107548031
# objective function at theta+ for step # 300
# -2.1115271135
# objective function at theta- for step # 300
# -2.11151894561
# objective function at theta+ for step # 400
# -2.11180631916
# objective function at theta- for step # 400
# -2.11182003095
# objective function at theta+ for step # 500
# -2.11205713384
# objective function at theta- for step # 500
# -2.11208614382
# objective function at theta+ for step # 600
# -2.1123203158
# objective function at theta- for step # 600
# -2.1123286117
# objective function at theta+ for step # 700
# -2.11243262652
# objective function at theta- for step # 700
# -2.11246081777
# Final objective function is: -2.11259181806
#
# OPTIMIZING HAMILTONIAN # 4 AT INTERATOMIC DISTANCE 0.6 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 0.984125095907
# objective function at theta+ for step # 0
# -0.75522407026
# objective function at theta- for step # 0
# -0.779447356196
# objective function at theta+ for step # 100
# -1.99251251111
# objective function at theta- for step # 100
# -1.99118222022
# objective function at theta+ for step # 200
# -1.99715120431
# objective function at theta- for step # 200
# -1.99696814876
# objective function at theta+ for step # 300
# -1.99746312678
# objective function at theta- for step # 300
# -1.99749111608
# objective function at theta+ for step # 400
# -1.99773769515
# objective function at theta- for step # 400
# -1.99772470078
# objective function at theta+ for step # 500
# -1.99775132481
# objective function at theta- for step # 500
# -1.99784694992
# objective function at theta+ for step # 600
# -1.99794438776
# objective function at theta- for step # 600
# -1.99794329516
# objective function at theta+ for step # 700
# -1.99804405866
# objective function at theta- for step # 700
# -1.99796713986
# Final objective function is: -1.99807827367
#
# OPTIMIZING HAMILTONIAN # 5 AT INTERATOMIC DISTANCE 0.7 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 2.64971245779
# objective function at theta+ for step # 0
# -0.839462422248
# objective function at theta- for step # 0
# -0.838727735569
# objective function at theta+ for step # 100
# -1.88204967328
# objective function at theta- for step # 100
# -1.88149960988
# objective function at theta+ for step # 200
# -1.89012015896
# objective function at theta- for step # 200
# -1.8903352123
# objective function at theta+ for step # 300
# -1.89175549698
# objective function at theta- for step # 300
# -1.89172725462
# objective function at theta+ for step # 400
# -1.89199664107
# objective function at theta- for step # 400
# -1.89201130446
# objective function at theta+ for step # 500
# -1.89209647361
# objective function at theta- for step # 500
# -1.8920960785
# objective function at theta+ for step # 600
# -1.89211372099
# objective function at theta- for step # 600
# -1.89209432867
# objective function at theta+ for step # 700
# -1.89209288037
# objective function at theta- for step # 700
# -1.89207868828
# Final objective function is: -1.89215223643
#
# OPTIMIZING HAMILTONIAN # 6 AT INTERATOMIC DISTANCE 0.8 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 1.02212576447
# objective function at theta+ for step # 0
# -1.24053580653
# objective function at theta- for step # 0
# -1.22485286281
# objective function at theta+ for step # 100
# -1.79524033139
# objective function at theta- for step # 100
# -1.79522053232
# objective function at theta+ for step # 200
# -1.79556169074
# objective function at theta- for step # 200
# -1.79549672963
# objective function at theta+ for step # 300
# -1.79556267675
# objective function at theta- for step # 300
# -1.79556385717
# objective function at theta+ for step # 400
# -1.79557464456
# objective function at theta- for step # 400
# -1.79558696584
# objective function at theta+ for step # 500
# -1.79558476707
# objective function at theta- for step # 500
# -1.79558182206
# objective function at theta+ for step # 600
# -1.79559238704
# objective function at theta- for step # 600
# -1.79559750663
# objective function at theta+ for step # 700
# -1.79555136587
# objective function at theta- for step # 700
# -1.79555163206
# Final objective function is: -1.7956149365
#
# OPTIMIZING HAMILTONIAN # 7 AT INTERATOMIC DISTANCE 0.9 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 1.81356861769
# objective function at theta+ for step # 0
# -0.916830009992
# objective function at theta- for step # 0
# -0.917552154154
# objective function at theta+ for step # 100
# -1.70762702168
# objective function at theta- for step # 100
# -1.70788137724
# objective function at theta+ for step # 200
# -1.70847096083
# objective function at theta- for step # 200
# -1.70844054433
# objective function at theta+ for step # 300
# -1.7085184304
# objective function at theta- for step # 300
# -1.70850031028
# objective function at theta+ for step # 400
# -1.70851629739
# objective function at theta- for step # 400
# -1.70851254321
# objective function at theta+ for step # 500
# -1.70851575105
# objective function at theta- for step # 500
# -1.70850554347
# objective function at theta+ for step # 600
# -1.70848021235
# objective function at theta- for step # 600
# -1.70847891281
# objective function at theta+ for step # 700
# -1.70851135369
# objective function at theta- for step # 700
# -1.7085148689
# Final objective function is: -1.70853447997
#
# OPTIMIZING HAMILTONIAN # 8 AT INTERATOMIC DISTANCE 1.0 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 1.33050833685
# objective function at theta+ for step # 0
# -0.937567594989
# objective function at theta- for step # 0
# -0.933969911024
# objective function at theta+ for step # 100
# -1.5815990702
# objective function at theta- for step # 100
# -1.58318009617
# objective function at theta+ for step # 200
# -1.62878496336
# objective function at theta- for step # 200
# -1.62854669168
# objective function at theta+ for step # 300
# -1.63021533915
# objective function at theta- for step # 300
# -1.63007512711
# objective function at theta+ for step # 400
# -1.63021765216
# objective function at theta- for step # 400
# -1.6302538137
# objective function at theta+ for step # 500
# -1.63026720669
# objective function at theta- for step # 500
# -1.63026376123
# objective function at theta+ for step # 600
# -1.6302654692
# objective function at theta- for step # 600
# -1.63027237084
# objective function at theta+ for step # 700
# -1.63030487424
# objective function at theta- for step # 700
# -1.63030432471
# Final objective function is: -1.63032640404
#
# OPTIMIZING HAMILTONIAN # 9 AT INTERATOMIC DISTANCE 1.1 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 2.45046481463
# objective function at theta+ for step # 0
# -0.939957700977
# objective function at theta- for step # 0
# -0.951690753928
# objective function at theta+ for step # 100
# -1.55184963112
# objective function at theta- for step # 100
# -1.55195745134
# objective function at theta+ for step # 200
# -1.56001747374
# objective function at theta- for step # 200
# -1.55987986744
# objective function at theta+ for step # 300
# -1.56018387955
# objective function at theta- for step # 300
# -1.56019542758
# objective function at theta+ for step # 400
# -1.56024827534
# objective function at theta- for step # 400
# -1.56024263519
# objective function at theta+ for step # 500
# -1.56022140614
# objective function at theta- for step # 500
# -1.56021518459
# objective function at theta+ for step # 600
# -1.56021866671
# objective function at theta- for step # 600
# -1.56022274791
# objective function at theta+ for step # 700
# -1.56020582259
# objective function at theta- for step # 700
# -1.56020634388
# Final objective function is: -1.56026320651
#
# OPTIMIZING HAMILTONIAN # 10 AT INTERATOMIC DISTANCE 1.2 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 1.87586580914
# objective function at theta+ for step # 0
# -0.958605005935
# objective function at theta- for step # 0
# -0.94120495346
# objective function at theta+ for step # 100
# -1.44925485162
# objective function at theta- for step # 100
# -1.44955615644
# objective function at theta+ for step # 200
# -1.46370073624
# objective function at theta- for step # 200
# -1.46403575275
# objective function at theta+ for step # 300
# -1.47598794568
# objective function at theta- for step # 300
# -1.47629425264
# objective function at theta+ for step # 400
# -1.48562874913
# objective function at theta- for step # 400
# -1.48614366692
# objective function at theta+ for step # 500
# -1.49151680693
# objective function at theta- for step # 500
# -1.49106553883
# objective function at theta+ for step # 600
# -1.49396433115
# objective function at theta- for step # 600
# -1.49419789824
# objective function at theta+ for step # 700
# -1.49578783035
# objective function at theta- for step # 700
# -1.49590420248
# Final objective function is: -1.49651027082
#
# OPTIMIZING HAMILTONIAN # 11 AT INTERATOMIC DISTANCE 1.3 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 1.47397131377
# objective function at theta+ for step # 0
# -1.11125076664
# objective function at theta- for step # 0
# -1.12013044577
# objective function at theta+ for step # 100
# -1.44175849013
# objective function at theta- for step # 100
# -1.44181852957
# objective function at theta+ for step # 200
# -1.44199883011
# objective function at theta- for step # 200
# -1.44208463331
# objective function at theta+ for step # 300
# -1.44211450866
# objective function at theta- for step # 300
# -1.44206823526
# objective function at theta+ for step # 400
# -1.4421687386
# objective function at theta- for step # 400
# -1.44216147724
# objective function at theta+ for step # 500
# -1.44218329643
# objective function at theta- for step # 500
# -1.4421875089
# objective function at theta+ for step # 600
# -1.44218148596
# objective function at theta- for step # 600
# -1.44217542447
# objective function at theta+ for step # 700
# -1.44217122181
# objective function at theta- for step # 700
# -1.44218761051
# Final objective function is: -1.442222893
#
# OPTIMIZING HAMILTONIAN # 12 AT INTERATOMIC DISTANCE 1.4 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 4.2573740487
# objective function at theta+ for step # 0
# -0.945173329965
# objective function at theta- for step # 0
# -0.945466074243
# objective function at theta+ for step # 100
# -1.39339448276
# objective function at theta- for step # 100
# -1.39334755337
# objective function at theta+ for step # 200
# -1.39340979336
# objective function at theta- for step # 200
# -1.39340458252
# objective function at theta+ for step # 300
# -1.39342058049
# objective function at theta- for step # 300
# -1.39342705468
# objective function at theta+ for step # 400
# -1.39339827635
# objective function at theta- for step # 400
# -1.39339829259
# objective function at theta+ for step # 500
# -1.39340088677
# objective function at theta- for step # 500
# -1.39340065532
# objective function at theta+ for step # 600
# -1.39340294648
# objective function at theta- for step # 600
# -1.39340299732
# objective function at theta+ for step # 700
# -1.39343709268
# objective function at theta- for step # 700
# -1.39343786358
# Final objective function is: -1.3934521847
#
# OPTIMIZING HAMILTONIAN # 13 AT INTERATOMIC DISTANCE 1.5 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 4.44860421652
# objective function at theta+ for step # 0
# -0.93670610339
# objective function at theta- for step # 0
# -0.940743201984
# objective function at theta+ for step # 100
# -1.34571971478
# objective function at theta- for step # 100
# -1.3455954295
# objective function at theta+ for step # 200
# -1.34888659017
# objective function at theta- for step # 200
# -1.34886520869
# objective function at theta+ for step # 300
# -1.34980533832
# objective function at theta- for step # 300
# -1.34990290018
# objective function at theta+ for step # 400
# -1.35027425238
# objective function at theta- for step # 400
# -1.35026352428
# objective function at theta+ for step # 500
# -1.35054602079
# objective function at theta- for step # 500
# -1.35044780681
# objective function at theta+ for step # 600
# -1.35065706638
# objective function at theta- for step # 600
# -1.35063345164
# objective function at theta+ for step # 700
# -1.35073221256
# objective function at theta- for step # 700
# -1.35073509326
# Final objective function is: -1.3507957034
#
# OPTIMIZING HAMILTONIAN # 14 AT INTERATOMIC DISTANCE 1.6 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 2.89882291201
# objective function at theta+ for step # 0
# -0.935411533459
# objective function at theta- for step # 0
# -0.925100524983
# objective function at theta+ for step # 100
# -1.30825375679
# objective function at theta- for step # 100
# -1.30827944012
# objective function at theta+ for step # 200
# -1.3104921052
# objective function at theta- for step # 200
# -1.3105003675
# objective function at theta+ for step # 300
# -1.31147372696
# objective function at theta- for step # 300
# -1.31146835248
# objective function at theta+ for step # 400
# -1.31201198622
# objective function at theta- for step # 400
# -1.3119727479
# objective function at theta+ for step # 500
# -1.31230944055
# objective function at theta- for step # 500
# -1.31232632666
# objective function at theta+ for step # 600
# -1.31258180397
# objective function at theta- for step # 600
# -1.31263184816
# objective function at theta+ for step # 700
# -1.31279714741
# objective function at theta- for step # 700
# -1.31278574986
# Final objective function is: -1.31299008745
#
# OPTIMIZING HAMILTONIAN # 15 AT INTERATOMIC DISTANCE 1.7 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 3.67623138547
# objective function at theta+ for step # 0
# -0.919117521863
# objective function at theta- for step # 0
# -0.921843557096
# objective function at theta+ for step # 100
# -1.22324286794
# objective function at theta- for step # 100
# -1.22340809186
# objective function at theta+ for step # 200
# -1.22816757836
# objective function at theta- for step # 200
# -1.2278595652
# objective function at theta+ for step # 300
# -1.23599049874
# objective function at theta- for step # 300
# -1.23601182081
# objective function at theta+ for step # 400
# -1.24529902052
# objective function at theta- for step # 400
# -1.24469938737
# objective function at theta+ for step # 500
# -1.25916387619
# objective function at theta- for step # 500
# -1.25843938216
# objective function at theta+ for step # 600
# -1.26634825626
# objective function at theta- for step # 600
# -1.26643717951
# objective function at theta+ for step # 700
# -1.27155473096
# objective function at theta- for step # 700
# -1.27114545242
# Final objective function is: -1.27529431708
#
# OPTIMIZING HAMILTONIAN # 16 AT INTERATOMIC DISTANCE 1.8 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 1.74082347208
# objective function at theta+ for step # 0
# -0.916203411699
# objective function at theta- for step # 0
# -0.903838543515
# objective function at theta+ for step # 100
# -1.20873535201
# objective function at theta- for step # 100
# -1.20871082145
# objective function at theta+ for step # 200
# -1.208854372
# objective function at theta- for step # 200
# -1.20885923057
# objective function at theta+ for step # 300
# -1.20899254652
# objective function at theta- for step # 300
# -1.20897006216
# objective function at theta+ for step # 400
# -1.20901112566
# objective function at theta- for step # 400
# -1.20901792189
# objective function at theta+ for step # 500
# -1.20919475968
# objective function at theta- for step # 500
# -1.20911816652
# objective function at theta+ for step # 600
# -1.20918126748
# objective function at theta- for step # 600
# -1.20922983341
# objective function at theta+ for step # 700
# -1.20931386139
# objective function at theta- for step # 700
# -1.2092711619
# Final objective function is: -1.20940022828
#
# OPTIMIZING HAMILTONIAN # 17 AT INTERATOMIC DISTANCE 1.9 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 3.60900152997
# objective function at theta+ for step # 0
# -0.962045594008
# objective function at theta- for step # 0
# -0.971795808144
# objective function at theta+ for step # 100
# -1.21840903054
# objective function at theta- for step # 100
# -1.21836752062
# objective function at theta+ for step # 200
# -1.22561826689
# objective function at theta- for step # 200
# -1.22570542622
# objective function at theta+ for step # 300
# -1.22727383777
# objective function at theta- for step # 300
# -1.22731126438
# objective function at theta+ for step # 400
# -1.22822841659
# objective function at theta- for step # 400
# -1.22811015602
# objective function at theta+ for step # 500
# -1.22883321747
# objective function at theta- for step # 500
# -1.22887113831
# objective function at theta+ for step # 600
# -1.22932179806
# objective function at theta- for step # 600
# -1.22935578408
# objective function at theta+ for step # 700
# -1.22975296488
# objective function at theta- for step # 700
# -1.2298712378
# Final objective function is: -1.23010151063
#
# OPTIMIZING HAMILTONIAN # 18 AT INTERATOMIC DISTANCE 2.0 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 1.86262070619
# objective function at theta+ for step # 0
# -0.89143166385
# objective function at theta- for step # 0
# -0.883991792831
# objective function at theta+ for step # 100
# -1.19066129287
# objective function at theta- for step # 100
# -1.19074102273
# objective function at theta+ for step # 200
# -1.19119887973
# objective function at theta- for step # 200
# -1.19136514141
# objective function at theta+ for step # 300
# -1.19166507601
# objective function at theta- for step # 300
# -1.19169512327
# objective function at theta+ for step # 400
# -1.19227899756
# objective function at theta- for step # 400
# -1.19208380047
# objective function at theta+ for step # 500
# -1.19257616281
# objective function at theta- for step # 500
# -1.19263918499
# objective function at theta+ for step # 600
# -1.1930718044
# objective function at theta- for step # 600
# -1.19312523159
# objective function at theta+ for step # 700
# -1.1935152121
# objective function at theta- for step # 700
# -1.19342313774
# Final objective function is: -1.19398342342
#
# OPTIMIZING HAMILTONIAN # 19 AT INTERATOMIC DISTANCE 2.1 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 1.70504113679
# objective function at theta+ for step # 0
# -0.880169232858
# objective function at theta- for step # 0
# -0.872932018089
# objective function at theta+ for step # 100
# -1.17974875738
# objective function at theta- for step # 100
# -1.17965709948
# objective function at theta+ for step # 200
# -1.18017817677
# objective function at theta- for step # 200
# -1.18019745714
# objective function at theta+ for step # 300
# -1.18039609714
# objective function at theta- for step # 300
# -1.1803581729
# objective function at theta+ for step # 400
# -1.18046349815
# objective function at theta- for step # 400
# -1.18048952672
# objective function at theta+ for step # 500
# -1.18054965295
# objective function at theta- for step # 500
# -1.18061115244
# objective function at theta+ for step # 600
# -1.18065020754
# objective function at theta- for step # 600
# -1.18064673377
# objective function at theta+ for step # 700
# -1.18066461969
# objective function at theta- for step # 700
# -1.18074697818
# Final objective function is: -1.18078401178
#
# OPTIMIZING HAMILTONIAN # 20 AT INTERATOMIC DISTANCE 2.2 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 1.90764799351
# objective function at theta+ for step # 0
# -0.864384155653
# objective function at theta- for step # 0
# -0.866758422316
# objective function at theta+ for step # 100
# -1.16940937008
# objective function at theta- for step # 100
# -1.16934116252
# objective function at theta+ for step # 200
# -1.16955809353
# objective function at theta- for step # 200
# -1.16949476346
# objective function at theta+ for step # 300
# -1.16962072592
# objective function at theta- for step # 300
# -1.16964159718
# objective function at theta+ for step # 400
# -1.16971776823
# objective function at theta- for step # 400
# -1.16968854488
# objective function at theta+ for step # 500
# -1.16979344974
# objective function at theta- for step # 500
# -1.16977291713
# objective function at theta+ for step # 600
# -1.16978950114
# objective function at theta- for step # 600
# -1.16987073794
# objective function at theta+ for step # 700
# -1.16986764926
# objective function at theta- for step # 700
# -1.16993483711
# Final objective function is: -1.16996752906
#
# OPTIMIZING HAMILTONIAN # 21 AT INTERATOMIC DISTANCE 2.3 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 2.47299651805
# objective function at theta+ for step # 0
# -0.851291262421
# objective function at theta- for step # 0
# -0.858427955507
# objective function at theta+ for step # 100
# -1.16399181338
# objective function at theta- for step # 100
# -1.16392032266
# objective function at theta+ for step # 200
# -1.16439629515
# objective function at theta- for step # 200
# -1.16432688722
# objective function at theta+ for step # 300
# -1.1645886498
# objective function at theta- for step # 300
# -1.16451527785
# objective function at theta+ for step # 400
# -1.16462774954
# objective function at theta- for step # 400
# -1.16467428568
# objective function at theta+ for step # 500
# -1.16477171009
# objective function at theta- for step # 500
# -1.16478079533
# objective function at theta+ for step # 600
# -1.16482736554
# objective function at theta- for step # 600
# -1.16485442717
# objective function at theta+ for step # 700
# -1.1649153664
# objective function at theta- for step # 700
# -1.16491406565
# Final objective function is: -1.16498293335
#
# OPTIMIZING HAMILTONIAN # 22 AT INTERATOMIC DISTANCE 2.4 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 2.53390486885
# objective function at theta+ for step # 0
# -0.850836680871
# objective function at theta- for step # 0
# -0.838153504314
# objective function at theta+ for step # 100
# -1.15098362228
# objective function at theta- for step # 100
# -1.15083485748
# objective function at theta+ for step # 200
# -1.15273662863
# objective function at theta- for step # 200
# -1.15294333262
# objective function at theta+ for step # 300
# -1.15348044735
# objective function at theta- for step # 300
# -1.15345769796
# objective function at theta+ for step # 400
# -1.15388125227
# objective function at theta- for step # 400
# -1.15393143481
# objective function at theta+ for step # 500
# -1.15415102408
# objective function at theta- for step # 500
# -1.15410933191
# objective function at theta+ for step # 600
# -1.15437224167
# objective function at theta- for step # 600
# -1.15441628846
# objective function at theta+ for step # 700
# -1.15450228519
# objective function at theta- for step # 700
# -1.1545765675
# Final objective function is: -1.1546464076
#
# OPTIMIZING HAMILTONIAN # 23 AT INTERATOMIC DISTANCE 2.5 ANGSTROM
#
# calibration step # 0 of 5
# calibrated SPSA_parameters[0] is 2.35324705888
# objective function at theta+ for step # 0
# -0.838134713791
# objective function at theta- for step # 0
# -0.830453651736
# objective function at theta+ for step # 100
# -1.14298117854
# objective function at theta- for step # 100
# -1.14295530233
# objective function at theta+ for step # 200
# -1.14347242505
# objective function at theta- for step # 200
# -1.14348621048
# objective function at theta+ for step # 300
# -1.14366662218
# objective function at theta- for step # 300
# -1.14369084775
# objective function at theta+ for step # 400
# -1.14380050526
# objective function at theta- for step # 400
# -1.14377459933
# objective function at theta+ for step # 500
# -1.14383330971
# objective function at theta- for step # 500
# -1.14382821443
# objective function at theta+ for step # 600
# -1.14386323578
# objective function at theta- for step # 600
# -1.14384410885

# %%
plt.plot(mol_distance,electr_energy+coulomb_repulsion,label='Exact')
if run_optimization:
    plt.plot(mol_distance,electr_energy_optimized+coulomb_repulsion,label='Optimized') 
plt.xlabel('Atomic distance (Angstrom)')
plt.ylabel('Energy')
plt.legend()
